# %%
# Load Isomap and UMAP measures, all or selected by un-commenting specific parts
# Join the above loaded shape info with Database-specific infomation: ATRIL, BIOSCA and CERMOI

# Add additional columns 'side' and 'SCA_side' to combined
# Add morphometry measures
# Add asymmetry index 

# verifications
# save the csv file if needed

# %%
import numpy as np
import pandas as pd
from scipy import stats
from scipy.stats import kruskal
import statsmodels.api as sm
from statsmodels.formula.api import ols
import seaborn as sns
import matplotlib.pyplot as plt

# %%
curRoot = 'C'  # 'C' or 'D'

# %% [markdown]
# # Define file name for shape measures, ORI, redo original for verifications
# curRegion = 'CSSyl' # CSSyl or CSpreCS    ###  modify  ###
# typeDist = 'min' #"min' or 'max'          ###  modify  ###
# typeSelect = 'ctl_sca1'                   ###  modify  ####
# typeTime = 'time1'                        ###  modify  ####
#
# shape_path = rf'{curRoot}:\B_projWIP\proj_ataxia\ORI\ORI_{typeTime}_{typeSelect}\{curRegion}\Isomap\isomapCmds{curRegion}k10d3dist{typeDist}.txt'
# shapeU_1_path = rf'{curRoot}:\B_projWIP\proj_ataxia\ORI\ORI_{typeTime}_{typeSelect}\{curRegion}\UMAP\dim1_{typeDist}_neig5_Dist0.2.txt'
# shapeU_2_path = rf'{curRoot}:\B_projWIP\proj_ataxia\ORI\ORI_{typeTime}_{typeSelect}\{curRegion}\UMAP\dim1_{typeDist}_neig30_Dist0.2.txt'
# shapeU_3_path = rf'{curRoot}:\B_projWIP\proj_ataxia\ORI\ORI_{typeTime}_{typeSelect}\{curRegion}\UMAP\dim2_{typeDist}_neig5_Dist0.2.txt'
# shapeU_4_path = rf'{curRoot}:\B_projWIP\proj_ataxia\ORI\ORI_{typeTime}_{typeSelect}\{curRegion}\UMAP\dim2_{typeDist}_neig30_Dist0.2.txt'

# %% [markdown]
# # Define file name for shape measures, SCA1, RELABELED
# curRegion = 'CSSyl' # CSSyl or CSpreCS    ###  modify  ###
# typeDist = 'max' #"min' or 'max'          ###  modify  ###
# typeSelect = 'ctl_sca1'                   ###  modify  ####
# typeTime = 'time1_2'                        ###  modify  #### 'time1', 'time2', 'time1_2'
# gen_BIOSCA = True                     ###  modify  ###
#
# shape_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL\relabel_{typeTime}_{typeSelect}\{curRegion}\Isomap\isomapCmds{curRegion}k10d3dist{typeDist}_BIOSCA.txt'
# shapeU_1_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL\relabel_{typeTime}_{typeSelect}\{curRegion}\UMAP\dim1_{typeDist}_neig5_Dist0.2_BIOSCA.txt'
# shapeU_2_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL\relabel_{typeTime}_{typeSelect}\{curRegion}\UMAP\dim1_{typeDist}_neig30_Dist0.2_BIOSCA.txt'
# shapeU_3_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL\relabel_{typeTime}_{typeSelect}\{curRegion}\UMAP\dim2_{typeDist}_neig5_Dist0.2_BIOSCA.txt'
# shapeU_4_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL\relabel_{typeTime}_{typeSelect}\{curRegion}\UMAP\dim2_{typeDist}_neig30_Dist0.2_BIOSCA.txt'
# if gen_BIOSCA:
#     shape_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL\relabel_{typeTime}_{typeSelect}\{curRegion}\Isomap\isomapCmds{curRegion}k10d3dist{typeDist}_BIOSCA.txt'
#     shapeU_1_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL\relabel_{typeTime}_{typeSelect}\{curRegion}\UMAP\dim1_{typeDist}_neig5_Dist0.2_BIOSCA.txt'
#     shapeU_2_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL\relabel_{typeTime}_{typeSelect}\{curRegion}\UMAP\dim1_{typeDist}_neig30_Dist0.2_BIOSCA.txt'
#     shapeU_3_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL\relabel_{typeTime}_{typeSelect}\{curRegion}\UMAP\dim2_{typeDist}_neig5_Dist0.2_BIOSCA.txt'
#     shapeU_4_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL\relabel_{typeTime}_{typeSelect}\{curRegion}\UMAP\dim2_{typeDist}_neig30_Dist0.2_BIOSCA.txt'

# %%
# Define file name for shape measures, SCA1, RELABELED REDO
curRegion = 'CSSyl'                       ###  modify  ###
typeDist = 'min' #"min' or 'max'          ###  modify  ###
typeSelect = 'ctl_sca1'                   ###  modify  ####
typeTime = 'time1_2'                        ###  modify  #### 'time1', 'time2', 'time1_2'
ben_BIOSCA = True

shape_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_REDO\RELABEL_REDO_{typeTime}_{typeSelect}\{curRegion}\Isomap\isomapCmds{curRegion}k10d3dist{typeDist}_BIOSCA.txt'
shapeU_1_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_REDO\RELABEL_REDO_{typeTime}_{typeSelect}\{curRegion}\UMAP\dim1_{typeDist}_neig5_Dist0.2_BIOSCA.txt'
shapeU_2_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_REDO\RELABEL_REDO_{typeTime}_{typeSelect}\{curRegion}\UMAP\dim1_{typeDist}_neig30_Dist0.2_BIOSCA.txt'
shapeU_3_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_REDO\RELABEL_REDO_{typeTime}_{typeSelect}\{curRegion}\UMAP\dim2_{typeDist}_neig5_Dist0.2_BIOSCA.txt'
shapeU_4_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_REDO\RELABEL_REDO_{typeTime}_{typeSelect}\{curRegion}\UMAP\dim2_{typeDist}_neig30_Dist0.2_BIOSCA.txt'
if gen_BIOSCA:
    shape_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_REDO\RELABEL_REDO_{typeTime}_{typeSelect}\{curRegion}\Isomap\isomapCmds{curRegion}k10d3dist{typeDist}_BIOSCA.txt'
    shapeU_1_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_REDO\RELABEL_REDO_{typeTime}_{typeSelect}\{curRegion}\UMAP\dim1_{typeDist}_neig5_Dist0.2_BIOSCA.txt'
    shapeU_2_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_REDO\RELABEL_REDO_{typeTime}_{typeSelect}\{curRegion}\UMAP\dim1_{typeDist}_neig30_Dist0.2_BIOSCA.txt'
    shapeU_3_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_REDO\RELABEL_REDO_{typeTime}_{typeSelect}\{curRegion}\UMAP\dim2_{typeDist}_neig5_Dist0.2_BIOSCA.txt'
    shapeU_4_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_REDO\RELABEL_REDO_{typeTime}_{typeSelect}\{curRegion}\UMAP\dim2_{typeDist}_neig30_Dist0.2_BIOSCA.txt'

# %% [markdown]
# # Define file name for shape measures, RELABELED ctl + sca7, sca3 and sca2
# curRegion = 'CSpreCS'                       ###  modify  ###
# typeDist = 'max' #"min' or 'max'       ###  modify  ###
# typeSelect = 'sca3'                    ###  modify  ###
# typeTime = 'time1_2'                   ###  modify  #### 'time1', 'time2', 'time1_2'
# gen_BIOSCA = False                     ###  modify  ###
#
# shape_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_{typeSelect}\{curRegion}\Isomap\isomapCmds{curRegion}k10d3dist{typeDist}.txt'
# shapeU_1_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_{typeSelect}\{curRegion}\UMAP\dim1_{typeDist}_neig5_Dist0.2.txt'
# shapeU_2_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_{typeSelect}\{curRegion}\UMAP\dim1_{typeDist}_neig30_Dist0.2.txt'
# shapeU_3_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_{typeSelect}\{curRegion}\UMAP\dim2_{typeDist}_neig5_Dist0.2.txt'
# shapeU_4_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_{typeSelect}\{curRegion}\UMAP\dim2_{typeDist}_neig30_Dist0.2.txt'
#
# if gen_BIOSCA:
#     shape_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_{typeSelect}\{curRegion}\Isomap\isomapCmds{curRegion}k10d3dist{typeDist}_BIOSCA.txt'
#     shapeU_1_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_{typeSelect}\{curRegion}\UMAP\dim1_{typeDist}_neig5_Dist0.2_BIOSCA.txt'
#     shapeU_2_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_{typeSelect}\{curRegion}\UMAP\dim1_{typeDist}_neig30_Dist0.2_BIOSCA.txt'
#     shapeU_3_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_{typeSelect}\{curRegion}\UMAP\dim2_{typeDist}_neig5_Dist0.2_BIOSCA.txt'
#     shapeU_4_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_{typeSelect}\{curRegion}\UMAP\dim2_{typeDist}_neig30_Dist0.2_BIOSCA.txt'

# %% [markdown]
# # Define file name for shape measures, time 1
# curRegion = 'CSpreCS' # CSSyl or CSpreCS  ###  modify  ###
# select = True                            ###  modify  ###
# typeDist = 'max' #"min' or 'max'          ###  modify  ###
# typeSelect = 'ctl_7'                      ###  modify  ####
# #'ctl_2', 'ctl_3', 'ctl_7', 'sca_1_7', 'ctl_1_7', 'BIOSCA', 'CERMOI','1_2', '2_3', 'BIOSCA_1_2', 'BIOSCA_2_3'
#
# if select == False:
#     shape_path = rf'{curRoot}:\B_projWIP\proj_ataxia\atrilBioscaCermoi\{curRegion}\Isomap_select\isomapCmds{curRegion}k10d3dist{typeDist}.txt'
#     shapeU_1_path = rf'{curRoot}:\B_projWIP\proj_ataxia\atrilBioscaCermoi\{curRegion}\UMAP_select\dim1_neig5_{typeDist}Dist0.2.txt'
#     shapeU_2_path = rf'{curRoot}:\B_projWIP\proj_ataxia\atrilBioscaCermoi\{curRegion}\UMAP_select\dim1_neig30_{typeDist}Dist0.2.txt'
#     shapeU_3_path = rf'{curRoot}:\B_projWIP\proj_ataxia\atrilBioscaCermoi\{curRegion}\UMAP_select\dim2_neig5_{typeDist}Dist0.2.txt'
#     shapeU_4_path = rf'{curRoot}:\B_projWIP\proj_ataxia\atrilBioscaCermoi\{curRegion}\UMAP_select\dim2_neig30_{typeDist}Dist0.2.txt'
#     #shapeU_4_path = rf'{curRoot}:\B_projWIP\proj_ataxia\atrilBioscaCermoi\{curRegion}\UMAP\dim3_neig5_minDist0.2.txt'
# else:
#     shape_path = rf'{curRoot}:\B_projWIP\proj_ataxia\atrilBioscaCermoi\{curRegion}\Isomap_select\isomapCmds{curRegion}k10d3dist{typeDist}_{typeSelect}.txt'
#     shapeU_1_path = rf'{curRoot}:\B_projWIP\proj_ataxia\atrilBioscaCermoi\{curRegion}\UMAP_select\dim1_{typeSelect}_{typeDist}_neig5_dist0.2.txt'
#     shapeU_2_path = rf'{curRoot}:\B_projWIP\proj_ataxia\atrilBioscaCermoi\{curRegion}\UMAP_select\dim1_{typeSelect}_{typeDist}_neig30_dist0.2.txt'
#     shapeU_3_path = rf'{curRoot}:\B_projWIP\proj_ataxia\atrilBioscaCermoi\{curRegion}\UMAP_select\dim2_{typeSelect}_{typeDist}_neig5_dist0.2.txt'
#     shapeU_4_path = rf'{curRoot}:\B_projWIP\proj_ataxia\atrilBioscaCermoi\{curRegion}\UMAP_select\dim2_{typeSelect}_{typeDist}_neig30_dist0.2.txt'

# %% [markdown]
# # Define file name for shape measures, time 2
# curRegion = 'CSSyl'
# select = False
# #baseName = 'ABC_time1_ctl_sca1_time2'
# #baseName = 'ctl_sca1_time1'              ###   CHANGE   ###
# baseName = 'ctl_sca1_time1_and_2'              ###   CHANGE   ###
# typeDist = 'max' #"min' or 'max'         ###   CHANGE   ###
# typeSelect = False #'ctl_1', 'ctl_2', 'ctl_3', 'ctl_7', 'sca_1_7', 'ctl_1_7', 'BIOSCA', 'CERMOI','1_2', '2_3', 'BIOSCA_1_2', 'BIOSCA_2_3'
#
# if select == False:
#     shape_path = rf'{curRoot}:\B_projWIP\proj_ataxia\atrilBioscaCermoi_add_time2\{curRegion}\Isomap_select\{baseName}\isomapCmds{curRegion}k10d3dist{typeDist}.txt'
#     shapeU_1_path = rf'{curRoot}:\B_projWIP\proj_ataxia\atrilBioscaCermoi_add_time2\{curRegion}\UMAP_select\{baseName}\dim1_{typeDist}_neig5_dist0.2.txt'
#     shapeU_2_path = rf'{curRoot}:\B_projWIP\proj_ataxia\atrilBioscaCermoi_add_time2\{curRegion}\UMAP_select\{baseName}\dim1_{typeDist}_neig30_dist0.2.txt'
#     shapeU_3_path = rf'{curRoot}:\B_projWIP\proj_ataxia\atrilBioscaCermoi_add_time2\{curRegion}\UMAP_select\{baseName}\dim2_{typeDist}_neig5_dist0.2.txt'
#     shapeU_4_path = rf'{curRoot}:\B_projWIP\proj_ataxia\atrilBioscaCermoi_add_time2\{curRegion}\UMAP_select\{baseName}\dim2_{typeDist}_neig30_dist0.2.txt'
#     #shapeU_4_path = rf'{curRoot}:\B_projWIP\proj_ataxia\atrilBioscaCermoi_add_time2\{curRegion}\UMAP_select\{baseName}\dim3_{typeDist}_neig5_dist0.2.txt'
#
# else:
#     shape_path = rf'{curRoot}:\B_projWIP\proj_ataxia\atrilBioscaCermoi_add_time2\{curRegion}\Isomap_select\{baseName}\isomapCmds{curRegion}k10d3dist{typeDist}_{typeSelect}.txt'
#     shapeU_1_path = rf'{curRoot}:\B_projWIP\proj_ataxia\atrilBioscaCermoi_add_time2\{curRegion}\UMAP_select\{baseName}\dim1_{typeSelect}_{typeDist}_neig5_dist0.2.txt'
#     shapeU_2_path = rf'{curRoot}:\B_projWIP\proj_ataxia\atrilBioscaCermoi_add_time2\{curRegion}\UMAP_select\{baseName}\dim1_{typeSelect}_{typeDist}_neig30_dist0.2.txt'
#     shapeU_3_path = rf'{curRoot}:\B_projWIP\proj_ataxia\atrilBioscaCermoi_add_time2\{curRegion}\UMAP_select\{baseName}\dim2_{typeSelect}_{typeDist}_neig5_dist0.2.txt'
#     shapeU_4_path = rf'{curRoot}:\B_projWIP\proj_ataxia\atrilBioscaCermoi_add_time2\{curRegion}\UMAP_select\{baseName}\dim2_{typeSelect}_{typeDist}_neig30_dist0.2.txt'

# %%
#######################  Load shape information  #######################
try:
    shape = pd.read_csv(shape_path, index_col=0, header=0)
    #print(shape.head())
    shapeU_1 = pd.read_csv(shapeU_1_path, index_col=0, header=0)
    shapeU_2 = pd.read_csv(shapeU_2_path, index_col=0, header=0)
    shapeU_3 = pd.read_csv(shapeU_3_path, index_col=0, header=0)
    shapeU_4 = pd.read_csv(shapeU_4_path, index_col=0, header=0)

    shapeU_1.rename(columns={'UMAP1': 'UMAP1_U1'}, inplace=True)
    shapeU_2.rename(columns={'UMAP1': 'UMAP1_U2'}, inplace=True)
    shapeU_3.rename(columns={'UMAP1': 'UMAP1_U3', 'UMAP2': 'UMAP2_U3'}, inplace=True)
    shapeU_4.rename(columns={'UMAP1': 'UMAP1_U4', 'UMAP2': 'UMAP2_U4'}, inplace=True)
    #shapeU_4.rename(columns={'UMAP1': 'UMAP1_U4', 'UMAP2': 'UMAP2_U4','UMAP3': 'UMAP3_U4'}, inplace=True)
except FileNotFoundError as e:
    print(f"Error: {e}")

#shape_joined = shape.join(shapeU)
shape_joined = shape.join([shapeU_1, shapeU_2, shapeU_3, shapeU_4])
shape = shape_joined
#print(len(shape))
#print(shape.head())
print(shape)
# Out:
#                           1         2         3   UMAP1_U1   UMAP1_U2  \
# subjName
# L001013LF_E1       5.711371 -1.919906 -2.849386  -2.381642  14.551304
# L001015VJ_E1      -0.693369  7.359930 -0.584219  -9.006812  10.242742
# L001019DA_E1      -0.025035 -1.811493 -1.233355   2.678610  11.561266
# L001020HG_E1      -1.878227  3.509211  2.522047   3.804064   9.153913
# L001022LM_E1       0.849919  1.129659 -0.309606   2.480728  11.084186
# ...                     ...       ...       ...        ...        ...
# flip-R001095MP_E2  1.081017 -1.656193 -0.601970  -1.198750  12.788393
# flip-R001096BC_E2  2.906362 -3.095257 -1.948919   0.336941  13.575219
# flip-R001099GL_E2 -2.087823 -1.401180  3.118095   4.814449   8.219780
# flip-R001100PY_E2  3.255967 -1.085192  0.230179  12.937633  12.174386
# flip-R001101JO_E2  5.238900 -4.082581  3.665514  11.287521  15.100157
#
#                    UMAP1_U3   UMAP2_U3  UMAP1_U4  UMAP2_U4
# subjName
# ...

# %%
##################################### Join shape info with Database-specific infomation ####################################

# %%
#####################################  ATRIL  #####################################

# %%
# Load information for ATRIL
#ATRIL_info_path = rf'{curRoot}:\B_projWIP\proj_ataxia\ATRIL_M0_joy.csv'
ATRIL_info_path = rf'{curRoot}:\B_projWIP\proj_ataxia\ATRIL.csv'

try:
    ATRIL_info = pd.read_csv(ATRIL_info_path, index_col=0, header=0,sep=';')
except FileNotFoundError as e:
    print(f"Error: {e}")

# Reset index to make old index 'SUBJECT_REF' a column, index as integers starting from 0
ATRIL_info.reset_index(inplace=True)

# Create the new column 'subjName'
#ATRIL_info['subjName'] = ATRIL_info['SUBJECT_REF'].str.replace('-', '') + '_M0' # old, for only first time stamp
ATRIL_info['subjName'] = ATRIL_info['SUBJECT_REF'].str.replace('-', '')

# 'CAGlong' and 'Inclusion_Date'  copy to second line
# Group by 'subjName' and use 'transform' to propagate the values of 'CAGlong' and 'Inclusion_Date'
ATRIL_info['CAGlong'] = ATRIL_info.groupby('subjName')['CAGlong'].transform('first')
ATRIL_info['Inclusion_Date'] = ATRIL_info.groupby('subjName')['Inclusion_Date'].transform('first')

# Create the new 'Time_point' column by using 'cumcount' within the groupby operation
ATRIL_info['Time_point'] = ATRIL_info.groupby('subjName').cumcount() + 1
ATRIL_info['Time_point'] = ATRIL_info['Time_point'].astype('int32')

# Update subjName, add _M0 or _M1 according to Time_point value
ATRIL_info['subjName'] = ATRIL_info.apply(lambda row: f"{row['subjName']}_M0" if row['Time_point'] == 1 
                                          else (f"{row['subjName']}_M1" if row['Time_point'] == 2 
                                          else row['subjName']), axis=1)

# Create a boolean mask for even and odd rows, even rows for M0, odd rows for M1, THIS CREATES ERROR when missing time points!!
#is_even_row = np.arange(len(ATRIL_info)) % 2 == 0
# Apply the mask to add '_M0' or '_M1' to even and odd rows to subjName
#ATRIL_info['subjName'] = ATRIL_info['subjName'] + ['_M0' if row % 2 == 0 else '_M1' for row in range(len(ATRIL_info))]

# Set 'subjName' as the new index
ATRIL_info.set_index('subjName', inplace=True)

# For column 'SCA', remove 'SCA' and keeping the values
ATRIL_info['SCA'] = ATRIL_info['SCA'].str.replace('SCA', '')
ATRIL_info['SCA'] = ATRIL_info['SCA'].astype(str)

# Add column CodeICM: ATRIL
ATRIL_info['CodeICM'] = 'ATRIL'

# Rename columns: 
# CAGlong to CAG, sex (1=M, 2=F) to Sex, age_calc to Age, Sara to SARA, inasscore to INAS, RANDOMIZATION (A=placebo, B=riluzole) to Randomization
ATRIL_info = ATRIL_info.rename(columns={'CAGlong':'CAG','sex (1=M, 2=F)':'Sex','age_calc':'Age','Sara':'SARA','inasscore':'INAS','RANDOMIZATION (A=placebo, B=riluzole)':'Randomization'})

# %%
# Double ATRIL_info to account for the two hemispheres
ATRIL_info_L = ATRIL_info.copy()
ATRIL_info_flip_R = ATRIL_info.copy()
# Append 'L' to the index of the first copy
ATRIL_info_L.index = 'L' + ATRIL_info_L.index
# Append 'flip_R' to the index of the second copy
ATRIL_info_flip_R.index = 'flip-R' + ATRIL_info_flip_R.index
# Compose the new info df with the new index
ATRIL_info_LR_combined = pd.concat([ATRIL_info_L, ATRIL_info_flip_R])

# Join INFO with shape measures
desired_columns = ['1', '2', '3','UMAP1_U1','UMAP1_U2','UMAP1_U3','UMAP2_U3','UMAP1_U4','UMAP2_U4'] 
# IF needing additional columns
#desired_columns = ['1', '2', '3','UMAP1_U1','UMAP1_U2','UMAP1_U3','UMAP2_U3','UMAP1_U4','UMAP2_U4','UMAP3_U4'] 

# Inner join on index
complete_info_ATRIL = ATRIL_info_LR_combined.merge(shape[desired_columns], how='inner', left_index=True, right_index=True)

# %%
#############################################   Verifications   ############################################
# Identify the missing indices
missing_indices = ATRIL_info_LR_combined.index.difference(complete_info_ATRIL.index)

# Display the missing indices
print("Missing indices from the smaller DataFrame (ATRIL_info_LR_combined):")
print(missing_indices)

# Display the rows themselves:
missing_rows = ATRIL_info_LR_combined.loc[missing_indices]
print("Missing rows from the smaller DataFrame (ATRIL_info_LR_combined):")
print(missing_rows)

print("Original data types:\n", complete_info_ATRIL.dtypes)
# Out:
# Missing indices from the smaller DataFrame (ATRIL_info_LR_combined):
# Index(['L0010001OP_M0', 'L0010001OP_M1', 'L0010002MV_M0', 'L0010002MV_M1',
#        'L0010003CJ_M0', 'L0010003CJ_M1', 'L0010004HV_M0', 'L0010004HV_M1',
#        'L0010005BC_M0', 'L0010005BC_M1',
#        ...
#        'flip-R0090001TT_M0', 'flip-R0090001TT_M1', 'flip-R0090002LL_M0',
#        'flip-R0090002LL_M1', 'flip-R0090003LJ_M0', 'flip-R0090003LJ_M1',
#        'flip-R0090004JP_M0', 'flip-R0090004JP_M1', 'flip-R0090005TM_M0',
#        'flip-R0090005TM_M1'],
#       dtype='object', name='subjName', length=178)
# Missing rows from the smaller DataFrame (ATRIL_info_LR_combined):
#                      SUBJECT_REF Randomization SCA   CAG  Sex        Age  \
# subjName
# L0010001OP_M0       001-0001-O-P             A   2  35.0    1  61.089665
# L0010001OP_M1       001-0001-O-P             A   2  35.0    1  62.091718
# L0010002MV_M0       001-0002-M-V             B   2  43.0    2  34.858316
# ...

# %%
################  for debug, save the file if needed
file_path = rf'D:\B_projWIP\proj_ataxia\{curRegion}_atril_test_add_time2.csv'
file_path_NaN = rf'D:\B_projWIP\proj_ataxia\{curRegion}_atril_test_NaN_show.csv'
#complete_info_ATRIL.to_csv(file_path, index=True)
#complete_info_ATRIL.to_csv(file_path_NaN, na_rep="NaN", index=True)
#ATRIL_info.to_csv(file_path_NaN, na_rep="NaN", index=True)

# %%
#######################################  BIOSCA  ###################################

# %%
# Load information for BIOSCA
#BIOSCA_info_path = rf'{curRoot}:\B_projWIP\proj_ataxia\BIOSCA_E1_joy.csv'
BIOSCA_info_path = rf'{curRoot}:\B_projWIP\proj_ataxia\BIOSCA_joy.csv' # added column 'laterality' to BIOSCA_E1_joy, oct 2024

try:
    # Try reading with ISO-8859-1 encoding
    BIOSCA_info = pd.read_csv(BIOSCA_info_path, index_col=0, header=0, encoding='ISO-8859-1')
except UnicodeDecodeError:
    # If ISO-8859-1 fails, try reading with Windows-1252 encoding
    BIOSCA_info = pd.read_csv(BIOSCA_info_path, index_col=0, header=0, encoding='Windows-1252')
except FileNotFoundError as e:
    print(f"Error: {e}")

# List of column names to remove
columns_to_remove = [str(i) for i in range(1, 12)]
BIOSCA_info.drop(columns=columns_to_remove, inplace=True, errors='ignore')

# Reset index to make 'CodeICM' a column
BIOSCA_info.reset_index(inplace=True)
# Create the new column 'subjName'
BIOSCA_info['NinclusionPatient'] = BIOSCA_info['NinclusionPatient'].astype(str).str.zfill(3)
#BIOSCA_info['subjName'] = '001' + BIOSCA_info['NinclusionPatient'] + BIOSCA_info['NomPatient'] + BIOSCA_info['PrénomPatient'] + '_E1'
BIOSCA_info['subjName'] = '001' + BIOSCA_info['NinclusionPatient'] + BIOSCA_info['NomPatient'] + BIOSCA_info['PrénomPatient']

# Rename columns: 
BIOSCA_info = BIOSCA_info.rename(columns={'CAGpatho':'CAG','sex':'Sex','age_start':'Age_onset','Group':'Group_ctl_pre_pat','Lateralité':'Handedness'})
# Convert to integer
BIOSCA_info['Group_ctl_pre_pat'] = BIOSCA_info['Group_ctl_pre_pat'].astype(int)

# Set SCA type as string
BIOSCA_info['SCA'] = BIOSCA_info['SCA'].astype(str)

# %%
# Fill up missing values with NaN
BIOSCA_info[['CAG', 'Age_onset']] = BIOSCA_info[['CAG', 'Age_onset']].fillna(np.nan)

# 1. Split the columns that contain stable information and those that change over time (like _V1, _V2)
stable_columns = ['subjName','SCA','CAG', 'Sex', 'Age_onset','Group_ctl_pre_pat','CodeICM','Handedness']
changing_columns = ['age_V1','age_V2','SARA_V1','SARA_V2','CCFS_V1','CCFS_V2']

# 2. Reshape (melt) time-varying columns. Use pd.melt() to "unpivot" the _V1 and _V2 columns into rows
melted_df = BIOSCA_info.melt(id_vars=stable_columns, value_vars=changing_columns, 
                    var_name='MeasureType', value_name='Value')

# 3. Extract time point information (_V1 or _V2) from 'MeasureType' and create 'Time_point'
melted_df['Time_point'] = melted_df['MeasureType'].apply(lambda x: 'V1' if '_V1' in x else 'V2')

# 4. Clean up 'MeasureType' to remove _V1/_V2 suffix
melted_df['MeasureType'] = melted_df['MeasureType'].str.replace('_V1', '').str.replace('_V2', '')

# 5. Pivot back to get each measure on its own column for each time point
# This doesn't work since pivot_table removes NaN values, use pivot instead
#final_df = melted_df.pivot_table(index=stable_columns + ['Time_point'], 
#                                 columns='MeasureType', values='Value').reset_index()
final_df = melted_df.pivot(index=stable_columns + ['Time_point'], columns='MeasureType', values='Value').reset_index()

# For column 'Time_point', remove 'V' and keeping the values
final_df['Time_point'] = final_df['Time_point'].str.replace('V', '')
final_df = final_df.rename(columns={'age':'Age'})

# Convert Time_point to integer
final_df['Time_point'] = final_df['Time_point'].astype(int)
# Update subjName, add _M0 or _M1 according to Time_point value
final_df['subjName'] = final_df.apply(lambda row: f"{row['subjName']}_E1" if row['Time_point'] == 1 
                                          else (f"{row['subjName']}_E2" if row['Time_point'] == 2 
                                          else row['subjName']), axis=1)
BIOSCA_info_melt = final_df.copy()

# Set subjName as index
BIOSCA_info_melt.set_index('subjName', inplace=True)

# Add the Disease_duration column
BIOSCA_info_melt['Disease_duration'] = BIOSCA_info_melt['Age'] - BIOSCA_info_melt['Age_onset']

BIOSCA_info = BIOSCA_info_melt

# %%
# Double BIOSCA_info_melt to account for the two hemisphere
BIOSCA_info_L = BIOSCA_info_melt.copy()
BIOSCA_info_flip_R = BIOSCA_info_melt.copy()
# Append 'L' to the index of the first copy
BIOSCA_info_L.index = 'L' + BIOSCA_info_L.index
# Append 'flip_R' to the index of the second copy
BIOSCA_info_flip_R.index = 'flip-R' + BIOSCA_info_flip_R.index
# Compose the new info df with the new index
BIOSCA_info_LR_combined = pd.concat([BIOSCA_info_L, BIOSCA_info_flip_R])

# Join INFO with shape measures
desired_columns = ['1', '2', '3','UMAP1_U1','UMAP1_U2','UMAP1_U3','UMAP2_U3','UMAP1_U4','UMAP2_U4'] 
# IF needing additional columns
#desired_columns = ['1', '2', '3','UMAP1_U1','UMAP1_U2','UMAP1_U3','UMAP2_U3','UMAP1_U4','UMAP2_U4','UMAP3_U4'] 

# Inner join on index, selecting desired columns from df2
complete_info_BIOSCA = BIOSCA_info_LR_combined.merge(shape[desired_columns], how='inner', left_index=True, right_index=True)

# %%
###########################################   Verifications   ######################################
# Identify the missing indices
missing_indices = BIOSCA_info_LR_combined.index.difference(complete_info_BIOSCA.index)

# Display the missing indices
print("Missing indices from the smaller DataFrame (BIOSCA_info_LR_combined):")
print(missing_indices)

# Display the rows themselves:
missing_rows = BIOSCA_info_LR_combined.loc[missing_indices]
#print("Missing rows from the smaller DataFrame (BIOSCA_info_LR_combined):")
#print(missing_rows)
# Out:
# Missing indices from the smaller DataFrame (BIOSCA_info_LR_combined):
# Index(['L001001MR_E1', 'L001001MR_E2', 'L001005DD_E1', 'L001005DD_E2',
#        'L001006DP_E1', 'L001006DP_E2', 'L001007DY_E1', 'L001007DY_E2',
#        'L001008JV_E1', 'L001008JV_E2',
#        ...
#        'flip-R001080FJ_E2', 'flip-R001082DB_E1', 'flip-R001082DB_E2',
#        'flip-R001086CP_E1', 'flip-R001086CP_E2', 'flip-R001088FP_E1',
#        'flip-R001088FP_E2', 'flip-R001092MD_E1', 'flip-R001092MD_E2',
#        'flip-R001094GE_E2'],
#       dtype='object', name='subjName', length=192)

# %%
# Check the data type after conversion
print("Data types after conversion:\n", complete_info_BIOSCA.dtypes)
# Out:
# Data types after conversion:
#  SCA                   object
# CAG                  float64
# Sex                    int64
# Age_onset            float64
# Group_ctl_pre_pat      int32
# CodeICM               object
# Handedness            object
# Time_point             int32
# CCFS                 float64
# SARA                 float64
# Age                  float64
# Disease_duration     float64
# 1                    float64
# 2                    float64
# 3                    float64
# UMAP1_U1             float64
# UMAP1_U2             float64
# UMAP1_U3             float64
# UMAP2_U3             float64
# UMAP1_U4             float64
# UMAP2_U4             float64
# dtype: object

# %%
print(len(complete_info_BIOSCA))
print(complete_info_BIOSCA.columns)
print(complete_info_BIOSCA.index)
print(len(shape[desired_columns]))
# Out:
# 132
# Index(['SCA', 'CAG', 'Sex', 'Age_onset', 'Group_ctl_pre_pat', 'CodeICM',
#        'Handedness', 'Time_point', 'CCFS', 'SARA', 'Age', 'Disease_duration',
#        '1', '2', '3', 'UMAP1_U1', 'UMAP1_U2', 'UMAP1_U3', 'UMAP2_U3',
#        'UMAP1_U4', 'UMAP2_U4'],
#       dtype='object')
# Index(['L001013LF_E1', 'L001013LF_E2', 'L001015VJ_E1', 'L001019DA_E1',
#        'L001019DA_E2', 'L001020HG_E1', 'L001020HG_E2', 'L001022LM_E1',
#        'L001022LM_E2', 'L001029DJ_E1',
#        ...
#        'flip-R001095MP_E1', 'flip-R001095MP_E2', 'flip-R001096BC_E1',
#        'flip-R001096BC_E2', 'flip-R001099GL_E1', 'flip-R001099GL_E2',
#        'flip-R001100PY_E1', 'flip-R001100PY_E2', 'flip-R001101JO_E1',
#        'flip-R001101JO_E2'],
#       dtype='object', name='subjName', length=132)
# 132

# %%
sca_counts = BIOSCA_info['SCA'].value_counts()
print(sca_counts)
# Out:
# SCA
# 3    38
# 0    38
# 1    34
# 7    26
# 2    26
# Name: count, dtype: int64

# %%
sca_counts = complete_info_BIOSCA['SCA'].value_counts()
print(sca_counts)
# Out:
# SCA
# 0    70
# 1    62
# Name: count, dtype: int64

# %%
# for debug, save the file if needed
file_path = rf'D:\B_projWIP\proj_ataxia\{curRegion}_biosca_test_add_time2.csv'
file_path_NaN = rf'D:\B_projWIP\proj_ataxia\{curRegion}_biosca_test_NaN_show.csv'
#complete_info_BIOSCA.to_csv(file_path, index=True)
#complete_info_BIOSCA.to_csv(file_path_NaN, na_rep="NaN", index=True)

file_path_NaN = rf'D:\B_projWIP\proj_ataxia\{curRegion}_biosca_info_NaN_show.csv'
#BIOSCA_info.to_csv(file_path_NaN, na_rep="NaN", index=True)

# %%
##############################  CERMOI  ###############################

# %%
# Load information for CERMOI
#CERMOI_info_path = rf'{curRoot}:\B_projWIP\proj_ataxia\CERMOI_V1_joy.csv'
CERMOI_info_path = rf'{curRoot}:\B_projWIP\proj_ataxia\CERMOI_joy.csv'

try:
    # Try reading with ISO-8859-1 encoding
    CERMOI_info = pd.read_csv(CERMOI_info_path, index_col=0, header=0, encoding='ISO-8859-1')
except UnicodeDecodeError:
    # If ISO-8859-1 fails, try reading with Windows-1252 encoding
    CERMOI_info = pd.read_csv(CERMOI_info_path, index_col=0, header=0, encoding='Windows-1252')
except FileNotFoundError as e:
    print(f"Error: {e}")
    
# Reset index to make 'ID' a column
CERMOI_info.reset_index(inplace=True) 
CERMOI_info.rename(columns={'ï»¿ID': 'ID'}, inplace=True)  # to remove unknown characters from the column name

# Transform the 'participant_id' column
CERMOI_info['subjName'] = CERMOI_info['participant_id'].str.replace('ICM', '')  # Remove 'ICM'
CERMOI_info['subjName'] = CERMOI_info['subjName'].str.replace('-', '')    # Remove all '-'
CERMOI_info['subjName'] = '00' + CERMOI_info['subjName']                   # Add '00' prefix
#CERMOI_info['subjName'] = CERMOI_info['subjName'] + '_V1'                  # Add '_V1' postfix

# Define the mapping from Group_CERMOI to SCA
group_to_sca = {1: '2', 2: '7', 3: '0'}
# Create the new column 'SCA' based on the mapping
#CERMOI_info['SCA'] = CERMOI_info['Group_CERMOI'].map(group_to_sca)
CERMOI_info['SCA'] = CERMOI_info['group (1=SCA2, 2=SCA7, 3=control)'].map(group_to_sca)

# Add column CodeICM: CERMOI
CERMOI_info['CodeICM'] = 'CERMOI'

# Convert 'allele1' and 'allele2' to numeric, coercing errors to NaN
CERMOI_info['allele1'] = pd.to_numeric(CERMOI_info['allele1'], errors='coerce')
CERMOI_info['allele2'] = pd.to_numeric(CERMOI_info['allele2'], errors='coerce')

# Add columns minAllele, maxAllele and avgAllele
CERMOI_info['minAllele'] = CERMOI_info[['allele1', 'allele2']].min(axis=1)
CERMOI_info['maxAllele'] = CERMOI_info[['allele1', 'allele2']].max(axis=1)
CERMOI_info['avgAllele'] = CERMOI_info[['allele1', 'allele2']].mean(axis=1)

# Add a column CAG, copy maxAllele
CERMOI_info['CAG'] = CERMOI_info['maxAllele']
# If SCA type is 0 (controls), assign the 'avgAllele' value instead
CERMOI_info.loc[CERMOI_info['SCA'] == 0, 'CAG'] = CERMOI_info['avgAllele']

# Rename columns: 
CERMOI_info = CERMOI_info.rename(columns={'gender':'Sex','Age at visit ':'Age','Age of first symptom':'Age_onset','Disease duration ':'Disease_duration','inas_count':'INAS'})

# %%
# copy to second and third line, group by 'ID' and use 'transform' to propagate the values
CERMOI_info['Sex'] = CERMOI_info.groupby('ID')['Sex'].transform('first')
CERMOI_info['Age_onset'] = CERMOI_info.groupby('ID')['Age_onset'].transform('first')
CERMOI_info['Disease_duration'] = CERMOI_info.groupby('ID')['Disease_duration'].transform('first')
CERMOI_info['subjName'] = CERMOI_info.groupby('ID')['subjName'].transform('first')
CERMOI_info['SCA'] = CERMOI_info.groupby('ID')['SCA'].transform('first')
CERMOI_info['CodeICM'] = CERMOI_info.groupby('ID')['CodeICM'].transform('first')
CERMOI_info['CAG'] = CERMOI_info.groupby('ID')['CAG'].transform('first')
CERMOI_info['allele1'] = CERMOI_info.groupby('ID')['allele1'].transform('first')
CERMOI_info['allele2'] = CERMOI_info.groupby('ID')['allele2'].transform('first')
CERMOI_info['minAllele'] = CERMOI_info.groupby('ID')['minAllele'].transform('first')
CERMOI_info['maxAllele'] = CERMOI_info.groupby('ID')['maxAllele'].transform('first')
CERMOI_info['avgAllele'] = CERMOI_info.groupby('ID')['avgAllele'].transform('first')
CERMOI_info['participant_id'] = CERMOI_info.groupby('ID')['participant_id'].transform('first')

########### add 0.5 and 1 to the second and third rows of Age for each ID ###########
# Function to propagate Age with offsets
def propagate_age(group):
    # Get the base age
    base_age = group['Age'].values
    # Create new values with the specified offsets
    new_ages = [base_age[0], base_age[0] + 0.5, base_age[0] + 1]
    # Return new ages with NaNs for other IDs
    return pd.Series(new_ages + [None] * (len(group) - 3), index=group.index)
# Apply the function to each group and fill in the Age column
CERMOI_info['Age'] = CERMOI_info.groupby('ID').apply(propagate_age).reset_index(drop=True)

# remove columns with redundant information
columns_to_remove = ['group (1=SCA2, 2=SCA7, 3=control)', 'birthyear','Visit ','visitdate']
CERMOI_info = CERMOI_info.drop(columns=columns_to_remove)

##############################  checking empty rows  #############################
#print(CERMOI_info['Age_onset'].unique())
#print(CERMOI_info['Disease_duration'].unique())

# Replace empty strings and other placeholders with np.nan if needed
CERMOI_info[['Age_onset', 'Disease_duration']] = CERMOI_info[['Age_onset', 'Disease_duration']].replace(' ', np.nan)

# Then, use pd.to_numeric with apply to convert non-numeric values to NaN
CERMOI_info['Age_onset'] = CERMOI_info['Age_onset'].apply(pd.to_numeric, errors='coerce')
CERMOI_info['Disease_duration'] = CERMOI_info['Disease_duration'].apply(pd.to_numeric, errors='coerce')
# Out:
# C:\Users\joyca\AppData\Local\Temp\ipykernel_83340\2738327779.py:26: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   CERMOI_info['Age'] = CERMOI_info.groupby('ID').apply(propagate_age).reset_index(drop=True)

# %%
# Create the new 'Time_point' column by using 'cumcount' within the groupby operation
CERMOI_info['Time_point'] = CERMOI_info.groupby('ID').cumcount() + 1
CERMOI_info['Time_point'] = CERMOI_info['Time_point'].astype('int32')

# Update subjName, add _M0 or _M1 according to Time_point value
CERMOI_info['subjName'] = CERMOI_info.apply(
    lambda row: f"{row['subjName']}_V1" if row['Time_point'] == 1 
    else (f"{row['subjName']}_V2" if row['Time_point'] == 2 
    else (f"{row['subjName']}_V3" if row['Time_point'] == 3 
    else row['subjName'])),
    axis=1
)
# Set 'subjName' as the new index
CERMOI_info.set_index('subjName', inplace=True)

CERMOI_info['SCA'] = CERMOI_info['SCA'].astype(str)
CERMOI_info['Sex'] = CERMOI_info['Sex'].astype('int64')
CERMOI_info['INAS'] = CERMOI_info['INAS'].astype('float64')
CERMOI_info['SARA'] = CERMOI_info['SARA'].astype('float64')
CERMOI_info['CodeICM'] = 'CERMOI'

# %%
# Double CERMOI_info to account for the two hemisphere
CERMOI_info_L = CERMOI_info.copy()
CERMOI_info_flip_R = CERMOI_info.copy()
# Append 'L' to the index of the first copy
CERMOI_info_L.index = 'L' + CERMOI_info_L.index
# Append 'flip_R' to the index of the second copy
CERMOI_info_flip_R.index = 'flip-R' + CERMOI_info_flip_R.index
# Compose the new info df with the new index
CERMOI_info_LR_combined = pd.concat([CERMOI_info_L, CERMOI_info_flip_R])

# Join INFO with shape measures
desired_columns = ['1', '2', '3','UMAP1_U1','UMAP1_U2','UMAP1_U3','UMAP2_U3','UMAP1_U4','UMAP2_U4'] 
# IF needing additional columns
#desired_columns = ['1', '2', '3','UMAP1_U1','UMAP1_U2','UMAP1_U3','UMAP2_U3','UMAP1_U4','UMAP2_U4','UMAP3_U4'] 

# Inner join on index, selecting desired columns from df2
complete_info_CERMOI = CERMOI_info_LR_combined.merge(shape[desired_columns], how='inner', left_index=True, right_index=True)

# %%
########################################  Verifications  #######################################
# Check the data type
print("Original data types:\n", complete_info_CERMOI.dtypes)
complete_info_CERMOI['SCA'] = complete_info_CERMOI['SCA'].astype(str)

print(complete_info_CERMOI.columns)
print(complete_info_CERMOI.index)
print(len(complete_info_CERMOI))
# Out:
# Original data types:
#  ID                    int64
# participant_id       object
# allele1             float64
# allele2             float64
# Sex                   int64
# Age                 float64
# Age_onset           float64
# Disease_duration    float64
# INAS                float64
# SARA                float64
# SCA                  object
# CodeICM              object
# minAllele           float64
# maxAllele           float64
# avgAllele           float64
# CAG                 float64
# Time_point            int32
# 1                   float64
# 2                   float64
# 3                   float64
# UMAP1_U1            float64
# UMAP1_U2            float64
# UMAP1_U3            float64
# UMAP2_U3            float64
# UMAP1_U4            float64
# UMAP2_U4            float64
# dtype: object
# Index(['ID', 'participant_id', 'allele1', 'allele2', 'Sex', 'Age', 'Age_onset',
#        'Disease_duration', 'INAS', 'SARA', 'SCA', 'CodeICM', 'minAllele',
# ...

# %%
# for debug, save the file if needed
file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_cermoi_test_add_time2.csv'
file_path_NaN = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_cermoi_test_NaN_show.csv'
#complete_info_CERMOI.to_csv(file_path_NaN, na_rep="NaN", index=True)
#complete_info_CERMOI.to_csv(file_path, index=True)

file_path_NaN = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_cermoi_info_NaN_show.csv'
#CERMOI_info.to_csv(file_path_NaN, na_rep="NaN", index=True)

# %%
#############################  Combining, Selection of col, adding 'side'  ##############################

# %%
# List of columns to select, add 'UMAP3_U4' if needed
#columns_to_select = ['CodeICM','age_V1','sex','SCA', 'SARA_V1','CAG','1', '2', '3','UMAP1_U1','UMAP1_U2','UMAP1_U3','UMAP2_U3','UMAP1_U4','UMAP2_U4' ]
col_ATRIL = ['Randomization','SCA','CAG','Sex','Age','SARA','INAS','Time_point','CodeICM','1','2','3','UMAP1_U1','UMAP1_U2','UMAP1_U3','UMAP2_U3','UMAP1_U4','UMAP2_U4']
col_BIOSCA = ['SCA','CAG','Sex','Age_onset','Group_ctl_pre_pat','CodeICM','Handedness','Time_point','CCFS','SARA','Age','Disease_duration','1','2','3','UMAP1_U1','UMAP1_U2','UMAP1_U3','UMAP2_U3','UMAP1_U4','UMAP2_U4']
col_CERMOI = ['allele1','allele2','Sex','Age','Age_onset','Disease_duration','INAS','SARA','SCA','CodeICM','CAG','Time_point','1','2','3','UMAP1_U1','UMAP1_U2','UMAP1_U3','UMAP2_U3','UMAP1_U4','UMAP2_U4']

# Create new DataFrames by selecting the specified columns
select_ATRIL = complete_info_ATRIL[col_ATRIL]
select_BIOSCA = complete_info_BIOSCA[col_BIOSCA]
select_CERMOI = complete_info_CERMOI[col_CERMOI]

#combined = pd.concat([select_ATRIL, select_BIOSCA, select_CERMOI], axis=0)
combined = pd.concat([select_ATRIL, select_BIOSCA, select_CERMOI], axis=0, join="outer")

# Rename the shape columns
column_mapping = {'1': 'iso1', '2': 'iso2', '3': 'iso3'}
combined.rename(columns=column_mapping, inplace=True)

# %%
print(select_ATRIL.index)
print(select_BIOSCA.index)
print(select_CERMOI.index)
# Out:
# Index([], dtype='object', name='subjName')
# Index(['L001013LF_E1', 'L001013LF_E2', 'L001015VJ_E1', 'L001019DA_E1',
#        'L001019DA_E2', 'L001020HG_E1', 'L001020HG_E2', 'L001022LM_E1',
#        'L001022LM_E2', 'L001029DJ_E1',
#        ...
#        'flip-R001095MP_E1', 'flip-R001095MP_E2', 'flip-R001096BC_E1',
#        'flip-R001096BC_E2', 'flip-R001099GL_E1', 'flip-R001099GL_E2',
#        'flip-R001100PY_E1', 'flip-R001100PY_E2', 'flip-R001101JO_E1',
#        'flip-R001101JO_E2'],
#       dtype='object', name='subjName', length=132)
# Index([], dtype='object', name='subjName')

# %%
index_list = combined.index.tolist()
print(index_list)
# Out:
# ['L001013LF_E1', 'L001013LF_E2', 'L001015VJ_E1', 'L001019DA_E1', 'L001019DA_E2', 'L001020HG_E1', 'L001020HG_E2', 'L001022LM_E1', 'L001022LM_E2', 'L001029DJ_E1', 'L001029DJ_E2', 'L001032SG_E1', 'L001032SG_E2', 'L001033BM_E1', 'L001033BM_E2', 'L001037GA_E1', 'L001037GA_E2', 'L001039CD_E1', 'L001039CD_E2', 'L001040BF_E1', 'L001040BF_E2', 'L001049BD_E1', 'L001049BD_E2', 'L001060MJ_E1', 'L001060MJ_E2', 'L001065BC_E1', 'L001065BC_E2', 'L001068RA_E1', 'L001068RA_E2', 'L001069DB_E1', 'L001069DB_E2', 'L001073PM_E1', 'L001073PM_E2', 'L001075HJ_E1', 'L001075HJ_E2', 'L001076SC_E1', 'L001076SC_E2', 'L001077MR_E1', 'L001077MR_E2', 'L001079LP_E1', 'L001079LP_E2', 'L001083RB_E1', 'L001083RB_E2', 'L001084CJ_E1', 'L001084CJ_E2', 'L001085BN_E1', 'L001085BN_E2', 'L001087RN_E1', 'L001087RN_E2', 'L001090RD_E1', 'L001090RD_E2', 'L001091MR_E1', 'L001091MR_E2', 'L001093TL_E1', 'L001093TL_E2', 'L001094GE_E1', 'L001095MP_E1', 'L001095MP_E2', 'L001096BC_E1', 'L001096BC_E2', 'L001099GL_E1', 'L001099GL_E2', 'L001
# ...

# %%
# Adding additional column: side and sca_side
def classify_index(index_name):
  """Classifies the index name with 'L' for 'l' and 'R' for 'f'."""
  if index_name.startswith('L'):
    return 'L'
  elif index_name.startswith('f'):
    return 'R'
  else:
    # Handle cases where the index doesn't start with 'l' or 'f' (optional)
    return None  # Or any other default value

# Add a column 'side' for the hemisphere of shape
combined['side'] = combined.index.map(classify_index)
# Adding additional column: SCA_side
combined['SCA_side'] = combined['SCA'].astype(str) + '_' + combined['side']

# Adding additional column: dominantSide and sca_dominantSide
combined['dominantSide'] = combined['Handedness'].replace({'Droite': 'L', 'Gauche': 'R'})
combined['SCA_dominantSide'] = combined['SCA'].astype(str) + '_' + combined['dominantSide']
# If no Handedness info, copy SCA_side to SCA_dominantSide
combined['SCA_dominantSide'] = combined['SCA_dominantSide'].fillna(combined['SCA_side'])

# %%
############################   Adding morphometry measures   ##############################

# %%
# Parameters
curRegionLeft = 'S.C._left'     ###  change   ###
curRegionRight = 'S.C._right'   ###  change   ###

def load_morphometry_measures(project_name, region_left, region_right, time_point_suffix, path_root):
    path_left = rf'{path_root}\{project_name}\{region_left}.csv'
    path_right = rf'{path_root}\{project_name}\{region_right}.csv'
    
    try:
        # Read the CSV files
        left = pd.read_csv(path_left, index_col=0, header=0, sep=';')
        right = pd.read_csv(path_right, index_col=0, header=0, sep=';')
    except FileNotFoundError as e:
        print(f"Error: {e}")
        return pd.DataFrame()  # Return an empty DataFrame if files are not found
    
    # Modify index and remove the 'side' column
    left.index = 'L' + left.index + time_point_suffix
    right.index = 'flip-R' + right.index + time_point_suffix
    del left['side']
    del right['side']
    # Combine left and right DataFrames
    return pd.concat([left, right], axis=0)

path_root = rf'{curRoot}:\B_projWIP\proj_ataxia\measures'
# Load data for each project, time point 1
Atril_measures = load_morphometry_measures('Atril', curRegionLeft, curRegionRight, '_M0', path_root)
Biosca_measures = load_morphometry_measures('Biosca', curRegionLeft, curRegionRight, '_E1', path_root)
Cermoi_measures = load_morphometry_measures('Cermoi', curRegionLeft, curRegionRight, '_V1', path_root)

path_root = rf'{curRoot}:\B_projWIP\proj_ataxia\measures_time2'
# Load data for each project, time point 2
Atril_measures_time2 = load_morphometry_measures('Atril_M12', curRegionLeft, curRegionRight, '_M12', path_root)
Biosca_measures_time2 = load_morphometry_measures('Biosca_E2', curRegionLeft, curRegionRight, '_E2', path_root)
Cermoi_measures_time2 = load_morphometry_measures('Cermoi_V3', curRegionLeft, curRegionRight, '_V3', path_root)

# %%
Atril_measures_time2
# Out:
#                        label  surface_talairach  surface_native  \
# subject
# L0010001OP_M12       b'S.C.'            4428.44         3396.53
# L0010002MV_M12       b'S.C.'            5771.11         4250.44
# L0010003CJ_M12       b'S.C.'            4505.36         3724.06
# L0010004HV_M12       b'S.C.'            5375.85         3500.26
# L0010005BC_M12       b'S.C.'            4264.05         3065.58
# ...                      ...                ...             ...
# flip-R0080002SH_M12  b'S.C.'            5097.88         3692.02
# flip-R0090001TT_M12  b'S.C.'            4281.49         3229.13
# flip-R0090002LL_M12  b'S.C.'            4214.78         3012.18
# flip-R0090004JP_M12  b'S.C.'            4600.62         3470.09
# flip-R0090005FM_M12  b'S.C.'            4634.22         3089.89
#
#                      maxdepth_talairach  maxdepth_native  meandepth_talairach  \
# subject
# L0010001OP_M12                    27.68            24.70                16.65
# ...

# %%
# Combining the information of measures from difference databases
combined_measures = pd.concat([Atril_measures, Biosca_measures, Cermoi_measures], axis=0)
combined_measures_time2 = pd.concat([Atril_measures_time2, Biosca_measures_time2, Cermoi_measures_time2], axis=0)
combined_measures_all = pd.concat([combined_measures,combined_measures_time2], axis=0)

# Writing the combined measures for a given region if needed
curRegion_measure = 'S.C.'
file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion_measure}_atrilBioscaCermoi_combined_measures_all.csv'
print(file_path)
# Write the DataFrame to a CSV file
#combined_measures_all.to_csv(file_path, index=True)
# Out:
# C:\B_projWIP\proj_ataxia\S.C._atrilBioscaCermoi_combined_measures_all.csv

# %%
# Combining the morphometry measures with all the rest of the information  ################################
combined_measures_allInfo = pd.merge(combined_measures_all, combined, left_index=True, right_index=True)

# Writing the combined measures and all the rest of the info for a given region if needed
curRegion_measure = 'S.C.'
file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion_measure}_atrilBioscaCermoi_combined_measures_after.csv'
print(file_path)
# Write the DataFrame to a CSV file
#combined_measures_allInfo.to_csv(file_path, index=True)
# Out:
# C:\B_projWIP\proj_ataxia\S.C._atrilBioscaCermoi_combined_measures_after.csv

# %%
################################  Verifications of the merging process  #################################
print(len(combined_measures))
print(len(combined))
print(len(combined_measures_allInfo))

# Determine the smaller DataFrame
smaller_df = combined_measures if len(combined_measures) < len(combined) else combined
# Find the lost indices only from the smaller DataFrame
lost_indices = smaller_df.index.difference(combined_measures_allInfo.index)

# Print the lost indices
print("Subjects lost from the smaller DataFrame:", lost_indices.tolist())
# Out:
# 360
# 132
# 132
# Subjects lost from the smaller DataFrame: []

# %%
####################  Add asymmetry Index: Separating sides, calculate asymmetry index, then recombine  #####################
# combined_complete replacing combined_measures_allInfo
# Make the subjName a column
combined_measures_allInfo['subjName'] = combined_measures_allInfo.index
# Separating sides, setting subjName as index
combined_complete_L = combined_measures_allInfo[combined_measures_allInfo['side'] == 'L'].set_index('subjName')
combined_complete_R = combined_measures_allInfo[combined_measures_allInfo['side'] == 'R'].set_index('subjName')

# Changing indexes so that we can calculate the asy index
combined_complete_L.index = combined_complete_L.index.str.lstrip('L')
combined_complete_R.index = combined_complete_R.index.str.lstrip('flip-R')

# Calculating and adding asy indexes
combined_complete_L['iso1_asy'] = (combined_complete_L['iso1'] - combined_complete_R['iso1'])/(combined_complete_L['iso1'] + combined_complete_R['iso1'])
combined_complete_R['iso1_asy'] = (combined_complete_L['iso1'] - combined_complete_R['iso1'])/(combined_complete_L['iso1'] + combined_complete_R['iso1'])
combined_complete_L['iso2_asy'] = (combined_complete_L['iso2'] - combined_complete_R['iso2'])/(combined_complete_L['iso2'] + combined_complete_R['iso2'])
combined_complete_R['iso2_asy'] = (combined_complete_L['iso2'] - combined_complete_R['iso2'])/(combined_complete_L['iso2'] + combined_complete_R['iso2'])
combined_complete_L['iso3_asy'] = (combined_complete_L['iso3'] - combined_complete_R['iso3'])/(combined_complete_L['iso3'] + combined_complete_R['iso3'])
combined_complete_R['iso3_asy'] = (combined_complete_L['iso3'] - combined_complete_R['iso3'])/(combined_complete_L['iso3'] + combined_complete_R['iso3'])

combined_complete_L['UMAP1_U1_asy'] = (combined_complete_L['UMAP1_U1']-combined_complete_R['UMAP1_U1'])/(combined_complete_L['UMAP1_U1']+combined_complete_R['UMAP1_U1'])
combined_complete_R['UMAP1_U1_asy'] = (combined_complete_L['UMAP1_U1']-combined_complete_R['UMAP1_U1'])/(combined_complete_L['UMAP1_U1']+combined_complete_R['UMAP1_U1'])
combined_complete_L['UMAP1_U2_asy'] = (combined_complete_L['UMAP1_U2']-combined_complete_R['UMAP1_U2'])/(combined_complete_L['UMAP1_U2']+combined_complete_R['UMAP1_U2'])
combined_complete_R['UMAP1_U2_asy'] = (combined_complete_L['UMAP1_U2']-combined_complete_R['UMAP1_U2'])/(combined_complete_L['UMAP1_U2']+combined_complete_R['UMAP1_U2'])
combined_complete_L['UMAP1_U3_asy'] = (combined_complete_L['UMAP1_U3']-combined_complete_R['UMAP1_U3'])/(combined_complete_L['UMAP1_U3']+combined_complete_R['UMAP1_U3'])
combined_complete_R['UMAP1_U3_asy'] = (combined_complete_L['UMAP1_U3']-combined_complete_R['UMAP1_U3'])/(combined_complete_L['UMAP1_U3']+combined_complete_R['UMAP1_U3'])
combined_complete_L['UMAP2_U3_asy'] = (combined_complete_L['UMAP2_U3']-combined_complete_R['UMAP2_U3'])/(combined_complete_L['UMAP2_U3']+combined_complete_R['UMAP2_U3'])
combined_complete_R['UMAP2_U3_asy'] = (combined_complete_L['UMAP2_U3']-combined_complete_R['UMAP2_U3'])/(combined_complete_L['UMAP2_U3']+combined_complete_R['UMAP2_U3'])
combined_complete_L['UMAP1_U4_asy'] = (combined_complete_L['UMAP1_U4']-combined_complete_R['UMAP1_U4'])/(combined_complete_L['UMAP1_U4']+combined_complete_R['UMAP1_U4'])
combined_complete_R['UMAP1_U4_asy'] = (combined_complete_L['UMAP1_U4']-combined_complete_R['UMAP1_U4'])/(combined_complete_L['UMAP1_U4']+combined_complete_R['UMAP1_U4'])
combined_complete_L['UMAP2_U4_asy'] = (combined_complete_L['UMAP2_U4']-combined_complete_R['UMAP2_U4'])/(combined_complete_L['UMAP2_U4']+combined_complete_R['UMAP2_U4'])
combined_complete_R['UMAP2_U4_asy'] = (combined_complete_L['UMAP2_U4']-combined_complete_R['UMAP2_U4'])/(combined_complete_L['UMAP2_U4']+combined_complete_R['UMAP2_U4'])


# 'surface_talairach', 'surface_native', 'maxdepth_talairach','maxdepth_native', 'meandepth_talairach', 'meandepth_native',
# 'hull_junction_length_talairach', 'hull_junction_length_native', 'GM_thickness', 'opening'
combined_complete_L['surface_talairach_asy'] = (combined_complete_L['surface_talairach'] - combined_complete_R['surface_talairach'])/(combined_complete_L['surface_talairach'] + combined_complete_R['surface_talairach'])
combined_complete_R['surface_talairach_asy'] = (combined_complete_L['surface_talairach'] - combined_complete_R['surface_talairach'])/(combined_complete_L['surface_talairach'] + combined_complete_R['surface_talairach'])
combined_complete_L['surface_native_asy'] = (combined_complete_L['surface_native'] - combined_complete_R['surface_native'])/(combined_complete_L['surface_native'] + combined_complete_R['surface_native'])
combined_complete_R['surface_native_asy'] = (combined_complete_L['surface_native'] - combined_complete_R['surface_native'])/(combined_complete_L['surface_native'] + combined_complete_R['surface_native'])

combined_complete_L['maxdepth_talairach_asy'] = (combined_complete_L['maxdepth_talairach'] - combined_complete_R['maxdepth_talairach'])/(combined_complete_L['maxdepth_talairach'] + combined_complete_R['maxdepth_talairach'])
combined_complete_R['maxdepth_talairach_asy'] = (combined_complete_L['maxdepth_talairach'] - combined_complete_R['maxdepth_talairach'])/(combined_complete_L['maxdepth_talairach'] + combined_complete_R['maxdepth_talairach'])
combined_complete_L['maxdepth_native_asy'] = (combined_complete_L['maxdepth_native'] - combined_complete_R['maxdepth_native'])/(combined_complete_L['maxdepth_native'] + combined_complete_R['maxdepth_native'])
combined_complete_R['maxdepth_native_asy'] = (combined_complete_L['maxdepth_native'] - combined_complete_R['maxdepth_native'])/(combined_complete_L['maxdepth_native'] + combined_complete_R['maxdepth_native'])

combined_complete_L['meandepth_talairach_asy'] = (combined_complete_L['meandepth_talairach'] - combined_complete_R['meandepth_talairach'])/(combined_complete_L['meandepth_talairach'] + combined_complete_R['meandepth_talairach'])
combined_complete_R['meandepth_talairach_asy'] = (combined_complete_L['meandepth_talairach'] - combined_complete_R['meandepth_talairach'])/(combined_complete_L['meandepth_talairach'] + combined_complete_R['meandepth_talairach'])
combined_complete_L['meandepth_native_asy'] = (combined_complete_L['meandepth_native'] - combined_complete_R['meandepth_native'])/(combined_complete_L['meandepth_native'] + combined_complete_R['meandepth_native'])
combined_complete_R['meandepth_native_asy'] = (combined_complete_L['meandepth_native'] - combined_complete_R['meandepth_native'])/(combined_complete_L['meandepth_native'] + combined_complete_R['meandepth_native'])

combined_complete_L['hull_junction_length_talairach_asy'] = (combined_complete_L['hull_junction_length_talairach'] - combined_complete_R['hull_junction_length_talairach'])/(combined_complete_L['hull_junction_length_talairach'] + combined_complete_R['hull_junction_length_talairach'])
combined_complete_R['hull_junction_length_talairach_asy'] = (combined_complete_L['hull_junction_length_talairach'] - combined_complete_R['hull_junction_length_talairach'])/(combined_complete_L['hull_junction_length_talairach'] + combined_complete_R['hull_junction_length_talairach'])
combined_complete_L['hull_junction_length_native_asy'] = (combined_complete_L['hull_junction_length_native'] - combined_complete_R['hull_junction_length_native'])/(combined_complete_L['hull_junction_length_native'] + combined_complete_R['hull_junction_length_native'])
combined_complete_R['hull_junction_length_native_asy'] = (combined_complete_L['hull_junction_length_native'] - combined_complete_R['hull_junction_length_native'])/(combined_complete_L['hull_junction_length_native'] + combined_complete_R['hull_junction_length_native'])

combined_complete_L['GM_thickness_asy'] = (combined_complete_L['GM_thickness'] - combined_complete_R['GM_thickness'])/(combined_complete_L['GM_thickness'] + combined_complete_R['GM_thickness'])
combined_complete_R['GM_thickness_asy'] = (combined_complete_L['GM_thickness'] - combined_complete_R['GM_thickness'])/(combined_complete_L['GM_thickness'] + combined_complete_R['GM_thickness'])
combined_complete_L['opening_asy'] = (combined_complete_L['opening'] - combined_complete_R['opening'])/(combined_complete_L['opening'] + combined_complete_R['opening'])
combined_complete_R['opening_asy'] = (combined_complete_L['opening'] - combined_complete_R['opening'])/(combined_complete_L['opening'] + combined_complete_R['opening'])

# Changing back the indexes so that we can concatenate L and R
combined_complete_L.index = 'L' + combined_complete_L.index.astype(str)
combined_complete_R.index = 'flip-R' + combined_complete_R.index.astype(str)
combined_complete = pd.concat([combined_complete_L, combined_complete_R], axis=0)

# %%
combined = combined_complete

# %%
##############################  Verifications  ###############################

# %%
print(combined_complete)
# Out:
#                      label  surface_talairach  surface_native  \
# subjName
# L001013LF_E1       b'S.C.'            3928.88         2673.83
# L001015VJ_E1       b'S.C.'            4982.84         3136.71
# L001019DA_E1       b'S.C.'            4437.42         3194.90
# L001020HG_E1       b'S.C.'            5164.57         3440.14
# L001022LM_E1       b'S.C.'            5684.75         3918.61
# ...                    ...                ...             ...
# flip-R001095MP_E2  b'S.C.'            4740.38         3092.95
# flip-R001096BC_E2  b'S.C.'            4889.02         3570.73
# flip-R001099GL_E2  b'S.C.'            4654.39         2961.74
# flip-R001100PY_E2  b'S.C.'            4832.07         3794.83
# flip-R001101JO_E2  b'S.C.'            4295.14         3348.90
#
#                    maxdepth_talairach  maxdepth_native  meandepth_talairach  \
# subjName
# L001013LF_E1                    24.64            19.96                16.56
# ...

# %%
print(combined.columns)
print(len(combined))
print(combined_complete.columns)
print(len(combined_complete))
# Out:
# Index(['label', 'surface_talairach', 'surface_native', 'maxdepth_talairach',
#        'maxdepth_native', 'meandepth_talairach', 'meandepth_native',
#        'hull_junction_length_talairach', 'hull_junction_length_native',
#        'GM_thickness', 'opening', 'Randomization', 'SCA', 'CAG', 'Sex', 'Age',
#        'SARA', 'INAS', 'Time_point', 'CodeICM', 'iso1', 'iso2', 'iso3',
#        'UMAP1_U1', 'UMAP1_U2', 'UMAP1_U3', 'UMAP2_U3', 'UMAP1_U4', 'UMAP2_U4',
#        'Age_onset', 'Group_ctl_pre_pat', 'Handedness', 'CCFS',
#        'Disease_duration', 'allele1', 'allele2', 'side', 'SCA_side',
#        'dominantSide', 'SCA_dominantSide', 'iso1_asy', 'iso2_asy', 'iso3_asy',
#        'UMAP1_U1_asy', 'UMAP1_U2_asy', 'UMAP1_U3_asy', 'UMAP2_U3_asy',
#        'UMAP1_U4_asy', 'UMAP2_U4_asy', 'surface_talairach_asy',
#        'surface_native_asy', 'maxdepth_talairach_asy', 'maxdepth_native_asy',
#        'meandepth_talairach_asy', 'meandepth_native_asy',
# ...

# %%
sca_counts = ATRIL_info['SCA'].value_counts()
print(sca_counts)

sca_counts = BIOSCA_info['SCA'].value_counts()
print(sca_counts)

sca_counts = CERMOI_info['SCA'].value_counts()
print(sca_counts)
# Out:
# SCA
# 2    89
# Name: count, dtype: int64
# SCA
# 3    38
# 0    38
# 1    34
# 7    26
# 2    26
# Name: count, dtype: int64
# SCA
# 2    45
# 7    45
# 0    30
# Name: count, dtype: int64

# %%
# Step 1: Check data types
print(combined['SCA'].dtype)
# Step 2: Convert all entries to strings (or integers, as needed)
combined['SCA'] = combined['SCA'].astype(str).str.strip()
# Step 3: Ensure all values are stripped of leading/trailing whitespace
combined['SCA'] = combined['SCA'].str.strip()
# Step 4: Recompute the value counts
sca_counts = combined['SCA'].value_counts()
# Print the cleaned summary
print(sca_counts)
# Out:
# object
# SCA
# 0    70
# 1    62
# Name: count, dtype: int64

# %%
# Display the values of the 'Age' column
print("Values in the 'CAG' column:")
print(combined['CAG'])

# Get a summary of statistics
summary_stats = combined['CAG'].describe()
print("\nSummary statistics for the 'CAG' column:")
print(summary_stats)
# Out:
# Values in the 'CAG' column:
# subjName
# L001013LF_E1         46.0
# L001015VJ_E1          NaN
# L001019DA_E1          NaN
# L001020HG_E1          NaN
# L001022LM_E1          NaN
#                      ...
# flip-R001095MP_E2    42.0
# flip-R001096BC_E2    47.0
# flip-R001099GL_E2     NaN
# flip-R001100PY_E2     NaN
# flip-R001101JO_E2     NaN
# Name: CAG, Length: 132, dtype: float64
#
# Summary statistics for the 'CAG' column:
# count    62.000000
# mean     46.774194
# std       6.192061
# min      40.000000
# 25%      42.000000
# 50%      45.000000
# 75%      49.500000
# max      62.000000
# Name: CAG, dtype: float64

# %%
# Detect null values in a specific column
null_values = combined['CAG'].isnull()
#print(null_values)

# Filter rows where the specified column has null values
null_rows = combined[combined['CAG'].isnull()]
#print(null_rows['CAG'])

# Count the number of null values in a specific column
null_count = combined['CAG'].isnull().sum()
print(f"Number of null values in 'column_name': {null_count}")
# Out:
# Number of null values in 'column_name': 70

# %%
cer = combined[combined['CodeICM'] == 'CERMOI']
print(cer['CAG'])
#print(combined.loc['L00030CA_V1']) # there are 4 subjects without CAG values

#is_null = combined.loc['L00030CA_V1', 'CAG'] is None or pd.isnull(combined.loc['L00030CA_V1', 'CAG'])
# Print the result
#print(is_null)
# Out:
# Series([], Name: CAG, dtype: float64)

# %%
combined.index
# Out:
# Index(['L001013LF_E1', 'L001015VJ_E1', 'L001019DA_E1', 'L001020HG_E1',
#        'L001022LM_E1', 'L001029DJ_E1', 'L001032SG_E1', 'L001033BM_E1',
#        'L001037GA_E1', 'L001039CD_E1',
#        ...
#        'flip-R001085BN_E2', 'flip-R001087RN_E2', 'flip-R001090RD_E2',
#        'flip-R001091MR_E2', 'flip-R001093TL_E2', 'flip-R001095MP_E2',
#        'flip-R001096BC_E2', 'flip-R001099GL_E2', 'flip-R001100PY_E2',
#        'flip-R001101JO_E2'],
#       dtype='object', name='subjName', length=132)

# %%
##########################  Saving csv files if needed  ###########################

# %%
####  for testing only, saving file with NaN shown  ####
#file_path = rf'D:\B_projWIP\proj_ataxia\{curRegion}_combined_test.csv'
#file_path_NaN = rf'D:\B_projWIP\proj_ataxia\{curRegion}_combined_test_NaN_show.csv'
#combined.to_csv(file_path_NaN, na_rep="NaN", index=True)
#combined.to_csv(file_path, index=True)

# %%
#curRegion defined at the beginning of the file 

writeFinal = True

#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_all_time1_{typeDist}.csv'

#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_ctl_sca1_time1_and_2_min.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_ctl_sca1_time1_and_2_max.csv'

#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_ctl_sca1_time1_min.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_ctl_sca1_time1_max.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_ctl_sca2_time1_min.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_ctl_sca2_time1_max.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_ctl_sca3_time1_min.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_ctl_sca3_time1_max.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_ctl_sca7_time1_min.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_ctl_sca7_time1_max.csv'

#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_ctl_sca1_time2_min.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_ctl_sca1_time2_max.csv'

############################  relabeled sca1  ############################
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL\relabel_{typeTime}_{typeSelect}\{curRegion}\combined_{typeTime}_{typeDist}_{typeSelect}.csv'
#if gen_BIOSCA:
#    file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL\relabel_{typeTime}_{typeSelect}\{curRegion}\combined_{typeTime}_{typeDist}_{typeSelect}_BIOSCA.csv'
    
############################  relabeled redo, sca1  ############################
file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_REDO\RELABEL_REDO_{typeTime}_{typeSelect}\{curRegion}\combined_{typeTime}_{typeDist}_{typeSelect}.csv'
if gen_BIOSCA:
    file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_REDO\RELABEL_REDO_{typeTime}_{typeSelect}\{curRegion}\combined_{typeTime}_{typeDist}_{typeSelect}_BIOSCA.csv'    

############################  relabeled sca7, ctl_sca3 and sca2  ############################
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_{typeSelect}\{curRegion}\combined_{typeTime}_{typeDist}_ctl_{typeSelect}.csv'
#if gen_BIOSCA: 
#    file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\RELABEL_{typeSelect}\{curRegion}\combined_{typeTime}_{typeDist}_ctl_{typeSelect}_BIOSCA.csv'

############################  ORI, redo for verification  ############################
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\ORI\ORI_{typeTime}_{typeSelect}\{curRegion}\combined_{typeTime}_{typeDist}_{typeSelect}.csv'


#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_sca1_7_min.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_sca1_7_max.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_ctl_sca1_7_min.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_ctl_sca1_7_max.csv'

#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_ctl_sca7_min.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_ctl_sca7_max.csv'

#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_ctl_sca1_min.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_ctl_sca1_max.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_ctl_sca2_min.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_ctl_sca2_max.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_ctl_sca3_min.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_ctl_sca3_max.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_ATRIL_min.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_ATRIL_max.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_BIOSCA_min.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_BIOSCA_max.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_CERMOI_min.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_CERMOI_max.csv'

#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_sca_l_2_min.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_sca_1_2_max.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_sca_2_3_min.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_sca_2_3_max.csv'

#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_BIOSCA_sca_1_2_min.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_BIOSCA_sca_1_2_max.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_BIOSCA_sca_2_3_min.csv'
#file_path = rf'{curRoot}:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_BIOSCA_sca_2_3_max.csv'

print(file_path)
# Write the DataFrame to a CSV file
if writeFinal:
    combined.to_csv(file_path, index=True)

# Test read the CSV file back into a DataFrame
#df_loaded = pd.read_csv(file_path)

#print(len(df_loaded))
#print("Data types:\n", df_loaded.dtypes)
#print(df_loaded)
# Out:
# C:\B_projWIP\proj_ataxia\RELABEL_REDO\RELABEL_REDO_time1_2_ctl_sca1\CSSyl\combined_time1_2_min_ctl_sca1_BIOSCA.csv
