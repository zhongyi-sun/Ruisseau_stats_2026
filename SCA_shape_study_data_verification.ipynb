# %%
# Loadinf data
# Verify the number of subjects, categories etc to ensre correctness

# %%
import pandas as pd

# %%
# Verify if distance matrix is consistant between RELABEL and RELABEL_REDO
curRegion = 'CSSYl'
distance_path_min = rf'D:\B_projWIP\proj_ataxia\RELABEL_REDO\RELABEL_REDO_time1_2_ctl_sca1\{curRegion}\Isomap\minDist{curRegion}.txt'
distance_path_max = rf'D:\B_projWIP\proj_ataxia\RELABEL_REDO\RELABEL_REDO_time1_2_ctl_sca1\{curRegion}\Isomap\maxDist{curRegion}.txt'

distance_path_min_relab1 = rf'D:\B_projWIP\proj_ataxia\RELABEL\relabel_time1_2_ctl_sca1\{curRegion}\Isomap\minDist{curRegion}.txt'
distance_path_max_relab1 = rf'D:\B_projWIP\proj_ataxia\RELABEL\relabel_time1_2_ctl_sca1\{curRegion}\Isomap\maxDist{curRegion}.txt'

try:
    minDist = pd.read_csv(distance_path_min, index_col=0, header=0)
    maxDist = pd.read_csv(distance_path_max, index_col=0, header=0) 
    minDist_relab1 = pd.read_csv(distance_path_min_relab1, index_col=0, header=0)
    maxDist_relab1 = pd.read_csv(distance_path_max_relab1, index_col=0, header=0)      
except FileNotFoundError as e:
    print(f"Error: {e}")

name1 = 'L001020HG_E1'
name2 = 'L001032SG_E2'
name3 = 'L00031CP_V1'
name4 = 'L001049BD_E2'

val = minDist.loc[name1,name2]
val1 = minDist_relab1.loc[name1,name2]
print(val)
print(val1)
val = minDist.loc[name3,name4]
val1 = minDist_relab1.loc[name3,name4]
print(val)
print(val1)
# Out:
# 5.232183857023903
# 5.232183857023903
# 6.1391501200848975
# 6.1391501200848975

# %%
curRegion = 'CSSyl'
# read in the subject name files
file_path_time1_forNames = rf'D:\B_projWIP\proj_ataxia\{curRegion}_combined_sca1_ctl_time1_names.csv'
file_path_time2_forNames = rf'D:\B_projWIP\proj_ataxia\{curRegion}_combined_sca1_ctl_time2_names.csv'

names_time1 = pd.read_csv(file_path_time1_forNames)
names_time2 = pd.read_csv(file_path_time2_forNames)

# %%
print(len(names_time1.index))
print(len(names_time2.index))
print(names_time2.fileNames)
# Out:
# 88
# 88
# 0         L001013LF_E2
# 1         L001015VJ_E2
# 2         L001019DA_E2
# 3         L001020HG_E2
# 4         L001022LM_E2
#             ...
# 83    flip-R00027EF_V3
# 84    flip-R00030CA_V3
# 85    flip-R00031CP_V3
# 86    flip-R00035NR_V3
# 87    flip-R00036DC_V3
# Name: fileNames, Length: 88, dtype: object

# %%
# read in the processed files after time2 calculations

#file_path = rf'D:\B_projWIP\proj_ataxia\Combined_Select_CSV\{curRegion}_ctl_sca1_time1_min.csv'
#file_path = rf'D:\B_projWIP\proj_ataxia\Combined_Select_CSV\{curRegion}_ctl_sca1_time1_max.csv'
file_path = rf'D:\B_projWIP\proj_ataxia\Combined_Select_CSV\{curRegion}_ctl_sca1_time2_min.csv'
#file_path = rf'D:\B_projWIP\proj_ataxia\Combined_Select_CSV\{curRegion}_ctl_sca1_time2_max.csv'

df_loaded = pd.read_csv(file_path)
names_loaded = df_loaded.subjName

print(len(df_loaded))
# Out:
# 82

# %%
# list the subjects missing from time2
list1 = names_time2.fileNames 
list2 = names_loaded
diff = list(set(list1) - set(list2))  # elements in list1 but NOT in list2
print(diff)
# Out:
# ['L001015VJ_E2', 'flip-R00020CT_V3', 'L00020CT_V3', 'L001094GE_E2', 'flip-R001015VJ_E2', 'flip-R001094GE_E2']

# %%
# get specific information of the missing subjects

curPath = rf'D:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_ctl_sca1_max.csv'
#curPath = rf'D:\B_projWIP\proj_ataxia\{curRegion}_atrilBioscaCermoi_combined_select_ctl_sca1_min.csv'

df_old_time1 = pd.read_csv(curPath)
#print(df_old_time1['subjName'].unique())  # print all subjName

print(df_old_time1['subjName'].dtype)
df_old_time1['subjName'] = df_old_time1['subjName'].astype(str) # convert subjName to type string if need

curSubjName = 'L001094GE_E1'
print('Current subject in dataframe:')
print(curSubjName in df_old_time1['subjName'].values)

filtered_df = df_old_time1[df_old_time1['subjName'] == curSubjName]
#print(filtered_df)  #print the whold row
print(filtered_df[['subjName','SCA','Time_point']])
# Out:
# object
# Current subject in dataframe:
# True
#         subjName  SCA  Time_point
# 28  L001094GE_E1    1           1

# %%
# read in the file after merging shape info with all the rest

#curPath = rf'D:\B_projWIP\proj_ataxia\Combined_Select_CSV\{curRegion}_ctl_sca1_time1_min.csv'
#curPath = rf'D:\B_projWIP\proj_ataxia\Combined_Select_CSV\{curRegion}_ctl_sca1_time1_max.csv'
#curPath = rf'D:\B_projWIP\proj_ataxia\Combined_Select_CSV\{curRegion}_ctl_sca1_time2_min.csv'
#curPath = rf'D:\B_projWIP\proj_ataxia\Combined_Select_CSV\{curRegion}_ctl_sca1_time2_max.csv'

curPath = rf'D:\B_projWIP\proj_ataxia\Combined_Select_CSV\{curRegion}_ctl_sca1_time1_and_2_min.csv'
#curPath = rf'D:\B_projWIP\proj_ataxia\Combined_Select_CSV\{curRegion}_ctl_sca1_time1_and_2_max.csv'

combined = pd.read_csv(curPath)
#names_loaded = df_loaded.subjName

print(len(combined))
# Out:
# 170

# %%
print(len(combined))
combined_time1 = combined[combined['Time_point']==1]
print(len(combined_time1))
combined_time2 = combined[combined['Time_point']!=1] # BIOSCA==2, CERMOI==3
print(len(combined_time2))
# Out:
# 170
# 88
# 82
